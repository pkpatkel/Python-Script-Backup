# %%
import pandas as pd
import pandas.io.sql as pd_sql
from pandas import Series, DataFrame, Panel
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
from matplotlib.backends.backend_pdf import PdfPages
from pylab import *
import datetime as date
import scipy.optimize
import scipy.stats
import seaborn as sns

# %%
## read excel file ###################################################################################################################
DB_Dump = pd.ExcelFile('eNEPAdmp_20180104.xlsx')
dmp_parse = DB_Dump.parse(sheetname='eNEPAdmp_20180104')
#####################################################################################################################################
# Add a column for the Fiscal Year, add a year to Due Dates: Oct - Dec
dmp_parse['Fiscal Year'] = dmp_parse['Comment Due Date'].dt.year
dmp_parse.loc[(dmp_parse['Comment Due Date'].dt.month > 9 ) & (dmp_parse['Comment Due Date'].dt.month <= 12), 'Fiscal Year'] = dmp_parse['Fiscal Year'] +1

# %%
### Plot a series of pdfs that show ratings for each agency ###
# Create colors
a, b, c, d, e, f, g, h, i, j, k =[plt.cm.Purples, 
                                  plt.cm.Blues, 
                                  plt.cm.Greens,
                                  plt.cm.Oranges, 
                                  plt.cm.Reds,
                                  plt.cm.cool,
                                  plt.cm.Wistia,
                                  plt.cm.hot,
                                  plt.cm.YlGn,
                                  plt.cm.RdPu,
                                  plt.cm.Greys, 
                                                ]
# First Ring (outside)
fig, ax = plt.subplots()
pp = PdfPages('AgencyDblPie'+date.datetime.now().strftime("%m_%d_%Y")+'.pdf')

# Get a list of the unique agencies in the dataset to loop through #
years = dmp_parse['Fiscal Year'].drop_duplicates().dropna()
#agencies = rated_all['Lead Agencies'].drop_duplicates().dropna()

#plot_df = rated_all.groupby('Lead Agencies')
plot_df = dmp_parse.groupby('Fiscal Year')

SMALL_SIZE = 8
MEDIUM_SIZE = 10
BIGGER_SIZE = 12

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

for year in years:
    if len(plot_df.get_group(year))>=1:
# GROUPS
        
        pltdf = plot_df.get_group(year)
        
        group_size=[len(pltdf.loc[(pltdf['Region'] == 1)]),
                    len(pltdf.loc[(pltdf['Region'] == 2)]),
                    len(pltdf.loc[(pltdf['Region'] == 3)]),
                    len(pltdf.loc[(pltdf['Region'] == 4)]),
                    len(pltdf.loc[(pltdf['Region'] == 5)]),
                    len(pltdf.loc[(pltdf['Region'] == 6)]),
                    len(pltdf.loc[(pltdf['Region'] == 7)]),
                    len(pltdf.loc[(pltdf['Region'] == 8)]),
                    len(pltdf.loc[(pltdf['Region'] == 9)]),
                    len(pltdf.loc[(pltdf['Region'] == 10)]),
                    len(pltdf.loc[(pltdf['Region'] == 11)]),
                   ] #dynamic
        
        group_names=['Region 1:'+str(group_size[0]), 
                     'Region 2:'+str(group_size[1]),
                     'Region 3:'+str(group_size[2]),
                     'Region 4:'+str(group_size[3]),
                     'Region 5:'+str(group_size[4]),
                     'Region 6:'+str(group_size[5]),
                     'Region 7:'+str(group_size[6]),
                     'Region 8:'+str(group_size[7]),
                     'Region 9:'+str(group_size[8]),
                     'Region 10:'+str(group_size[9]),
                     'Region 11:'+str(group_size[10]),
                    ]
        
                
        cmb_g = pd.DataFrame(
                {'names': group_names,
                 'size': group_size
                })
        cmb_g.loc[(cmb_g['size'] == 0), 'names'] = ''
        
# SUBGROUPS        
        
        subgroup_size=[len(pltdf.loc[(pltdf['Type'] == 'Draft')            & (pltdf['Region'] == 1)]),
                       len(pltdf.loc[(pltdf['Type'] == 'Draft Supplement') & (pltdf['Region'] == 1)]),
                       len(pltdf.loc[(pltdf['Type'] == 'Revised Draft')    & (pltdf['Region'] == 1)]),
                       len(pltdf.loc[(pltdf['Type'] == 'Final')            & (pltdf['Region'] == 1)]),
                       len(pltdf.loc[(pltdf['Type'] == 'Final Supplement') & (pltdf['Region'] == 1)]),
                       
                       len(pltdf.loc[(pltdf['Type'] == 'Draft')            & (pltdf['Region'] == 2)]),
                       len(pltdf.loc[(pltdf['Type'] == 'Draft Supplement') & (pltdf['Region'] == 2)]),
                       len(pltdf.loc[(pltdf['Type'] == 'Revised Draft')    & (pltdf['Region'] == 2)]),
                       len(pltdf.loc[(pltdf['Type'] == 'Final')            & (pltdf['Region'] == 2)]),
                       len(pltdf.loc[(pltdf['Type'] == 'Final Supplement') & (pltdf['Region'] == 2)]),
                       
                       len(pltdf.loc[(pltdf['Type'] == 'Draft')            & (pltdf['Region'] == 3)]),
                       len(pltdf.loc[(pltdf['Type'] == 'Draft Supplement') & (pltdf['Region'] == 3)]),
                       len(pltdf.loc[(pltdf['Type'] == 'Revised Draft')    & (pltdf['Region'] == 3)]),
                       len(pltdf.loc[(pltdf['Type'] == 'Final')            & (pltdf['Region'] == 3)]),
                       len(pltdf.loc[(pltdf['Type'] == 'Final Supplement') & (pltdf['Region'] == 3)]),
                       
                       len(pltdf.loc[(pltdf['Type'] == 'Draft')            & (pltdf['Region'] == 4)]),
                       len(pltdf.loc[(pltdf['Type'] == 'Draft Supplement') & (pltdf['Region'] == 4)]),
                       len(pltdf.loc[(pltdf['Type'] == 'Revised Draft')    & (pltdf['Region'] == 4)]),
                       len(pltdf.loc[(pltdf['Type'] == 'Final')            & (pltdf['Region'] == 4)]),
                       len(pltdf.loc[(pltdf['Type'] == 'Final Supplement') & (pltdf['Region'] == 4)]),                       

                       len(pltdf.loc[(pltdf['Type'] == 'Draft')            & (pltdf['Region'] == 5)]),
                       len(pltdf.loc[(pltdf['Type'] == 'Draft Supplement') & (pltdf['Region'] == 5)]),
                       len(pltdf.loc[(pltdf['Type'] == 'Revised Draft')    & (pltdf['Region'] == 5)]),
                       len(pltdf.loc[(pltdf['Type'] == 'Final')            & (pltdf['Region'] == 5)]),
                       len(pltdf.loc[(pltdf['Type'] == 'Final Supplement') & (pltdf['Region'] == 5)]),                       

                       len(pltdf.loc[(pltdf['Type'] == 'Draft')            & (pltdf['Region'] == 6)]),
                       len(pltdf.loc[(pltdf['Type'] == 'Draft Supplement') & (pltdf['Region'] == 6)]),
                       len(pltdf.loc[(pltdf['Type'] == 'Revised Draft')    & (pltdf['Region'] == 6)]),
                       len(pltdf.loc[(pltdf['Type'] == 'Final')            & (pltdf['Region'] == 6)]),
                       len(pltdf.loc[(pltdf['Type'] == 'Final Supplement') & (pltdf['Region'] == 6)]),                       

                       len(pltdf.loc[(pltdf['Type'] == 'Draft')            & (pltdf['Region'] == 7)]),
                       len(pltdf.loc[(pltdf['Type'] == 'Draft Supplement') & (pltdf['Region'] == 7)]),
                       len(pltdf.loc[(pltdf['Type'] == 'Revised Draft')    & (pltdf['Region'] == 7)]),
                       len(pltdf.loc[(pltdf['Type'] == 'Final')            & (pltdf['Region'] == 7)]),
                       len(pltdf.loc[(pltdf['Type'] == 'Final Supplement') & (pltdf['Region'] == 7)]),                       
                       
                       len(pltdf.loc[(pltdf['Type'] == 'Draft')            & (pltdf['Region'] == 8)]),
                       len(pltdf.loc[(pltdf['Type'] == 'Draft Supplement') & (pltdf['Region'] == 8)]),
                       len(pltdf.loc[(pltdf['Type'] == 'Revised Draft')    & (pltdf['Region'] == 8)]),
                       len(pltdf.loc[(pltdf['Type'] == 'Final')            & (pltdf['Region'] == 8)]),
                       len(pltdf.loc[(pltdf['Type'] == 'Final Supplement') & (pltdf['Region'] == 8)]),                       
                       
                       len(pltdf.loc[(pltdf['Type'] == 'Draft')            & (pltdf['Region'] == 9)]),
                       len(pltdf.loc[(pltdf['Type'] == 'Draft Supplement') & (pltdf['Region'] == 9)]),
                       len(pltdf.loc[(pltdf['Type'] == 'Revised Draft')    & (pltdf['Region'] == 9)]),
                       len(pltdf.loc[(pltdf['Type'] == 'Final')            & (pltdf['Region'] == 9)]),
                       len(pltdf.loc[(pltdf['Type'] == 'Final Supplement') & (pltdf['Region'] == 9)]),                       
                       
                       len(pltdf.loc[(pltdf['Type'] == 'Draft')            & (pltdf['Region'] == 10)]),
                       len(pltdf.loc[(pltdf['Type'] == 'Draft Supplement') & (pltdf['Region'] == 10)]),
                       len(pltdf.loc[(pltdf['Type'] == 'Revised Draft')    & (pltdf['Region'] == 10)]),
                       len(pltdf.loc[(pltdf['Type'] == 'Final')            & (pltdf['Region'] == 10)]),
                       len(pltdf.loc[(pltdf['Type'] == 'Final Supplement') & (pltdf['Region'] == 10)]),                       

                       len(pltdf.loc[(pltdf['Type'] == 'Draft')            & (pltdf['Region'] == 11)]),
                       len(pltdf.loc[(pltdf['Type'] == 'Draft Supplement') & (pltdf['Region'] == 11)]),
                       len(pltdf.loc[(pltdf['Type'] == 'Revised Draft')    & (pltdf['Region'] == 11)]),
                       len(pltdf.loc[(pltdf['Type'] == 'Final')            & (pltdf['Region'] == 11)]),
                       len(pltdf.loc[(pltdf['Type'] == 'Final Supplement') & (pltdf['Region'] == 11)])                      
                       
                  ] #dynamic
        
        subgroup_names=['Draft:'            +str(subgroup_size[0]), 
                        'Draft Supplement:' +str(subgroup_size[1]), 
                        'Revised Draft:'    +str(subgroup_size[2]), 
                        'Final:'            +str(subgroup_size[3]), 
                        'Final Supplement:' +str(subgroup_size[4]), 
                        'Draft:'            +str(subgroup_size[5]), 
                        'Draft Supplement:' +str(subgroup_size[6]), 
                        'Revised Draft:'    +str(subgroup_size[7]), 
                        'Final:'            +str(subgroup_size[8]), 
                        'Final Supplement:' +str(subgroup_size[9]),
                        'Draft:'            +str(subgroup_size[10]), 
                        'Draft Supplement:' +str(subgroup_size[11]), 
                        'Revised Draft:'    +str(subgroup_size[12]), 
                        'Final:'            +str(subgroup_size[13]), 
                        'Final Supplement:' +str(subgroup_size[14]),                         
                        'Draft:'            +str(subgroup_size[15]), 
                        'Draft Supplement:' +str(subgroup_size[16]), 
                        'Revised Draft:'    +str(subgroup_size[17]), 
                        'Final:'            +str(subgroup_size[18]), 
                        'Final Supplement:' +str(subgroup_size[19]),                         
                        'Draft:'            +str(subgroup_size[20]), 
                        'Draft Supplement:' +str(subgroup_size[21]), 
                        'Revised Draft:'    +str(subgroup_size[22]), 
                        'Final:'            +str(subgroup_size[23]), 
                        'Final Supplement:' +str(subgroup_size[24]),                         
                        'Draft:'            +str(subgroup_size[25]), 
                        'Draft Supplement:' +str(subgroup_size[26]), 
                        'Revised Draft:'    +str(subgroup_size[27]), 
                        'Final:'            +str(subgroup_size[28]), 
                        'Final Supplement:' +str(subgroup_size[29]),                         
                        'Draft:'            +str(subgroup_size[30]), 
                        'Draft Supplement:' +str(subgroup_size[31]), 
                        'Revised Draft:'    +str(subgroup_size[32]), 
                        'Final:'            +str(subgroup_size[33]), 
                        'Final Supplement:' +str(subgroup_size[34]),                         
                        'Draft:'            +str(subgroup_size[35]), 
                        'Draft Supplement:' +str(subgroup_size[36]), 
                        'Revised Draft:'    +str(subgroup_size[37]), 
                        'Final:'            +str(subgroup_size[38]), 
                        'Final Supplement:' +str(subgroup_size[39]),                         
                        'Draft:'            +str(subgroup_size[40]), 
                        'Draft Supplement:' +str(subgroup_size[41]), 
                        'Revised Draft:'    +str(subgroup_size[42]), 
                        'Final:'            +str(subgroup_size[43]), 
                        'Final Supplement:' +str(subgroup_size[44]),                         
                        'Draft:'            +str(subgroup_size[45]), 
                        'Draft Supplement:' +str(subgroup_size[46]), 
                        'Revised Draft:'    +str(subgroup_size[47]), 
                        'Final:'            +str(subgroup_size[48]), 
                        'Final Supplement:' +str(subgroup_size[49]),                         
                        'Draft:'            +str(subgroup_size[50]), 
                        'Draft Supplement:' +str(subgroup_size[51]), 
                        'Revised Draft:'    +str(subgroup_size[52]), 
                        'Final:'            +str(subgroup_size[53]), 
                        'Final Supplement:' +str(subgroup_size[54])                         
                       ]
        
        cmb_s = pd.DataFrame(
                {'names': subgroup_names,
                 'size': subgroup_size
                })
        cmb_s.loc[(cmb_s['size'] == 0), 'names'] = ''
        
        
        ax.axis('equal')
        mypie, _ = ax.pie(group_size, radius=1.3, labels=cmb_g['names'], colors=[a(0.6), 
                                                                                 b(0.6), 
                                                                                 c(0.6), 
                                                                                 d(0.6), 
                                                                                 e(0.6), 
                                                                                 f(0.6), 
                                                                                 g(0.6), 
                                                                                 h(0.6), 
                                                                                 i(0.6),
                                                                                 j(0.6),
                                                                                 k(0.6)] )
        plt.setp( mypie, width=0.3, edgecolor='white')
    
        # Second Ring (Inside)
        mypie2, _ = ax.pie(subgroup_size, radius=1.3-0.3, labels=cmb_s['names'], labeldistance=0.7, colors=[
                   a(0.4), 
                   a(0.4),
                   a(0.4),
                   a(0.4),
                   a(0.4),
                   b(0.4), 
                   b(0.4),
                   b(0.4),
                   b(0.4),
                   b(0.4),
                   c(0.4), 
                   c(0.4),
                   c(0.4),
                   c(0.4),
                   c(0.4),            
                   d(0.4), 
                   d(0.4),
                   d(0.4),
                   d(0.4),
                   d(0.4),            
                   e(0.4), 
                   e(0.4),
                   e(0.4),
                   e(0.4),
                   e(0.4),            
                   f(0.4), 
                   f(0.4),
                   f(0.4),
                   f(0.4),
                   f(0.4),            
                   g(0.4), 
                   g(0.4),
                   g(0.4),
                   g(0.4),
                   g(0.4),
                   h(0.4), 
                   h(0.4),
                   h(0.4),
                   h(0.4),
                   h(0.4),            
                   i(0.4), 
                   i(0.4),
                   i(0.4),
                   i(0.4),
                   i(0.4),            
                   j(0.4), 
                   j(0.4),
                   j(0.4),
                   j(0.4),
                   j(0.4),            
                   k(0.4), 
                   k(0.4),
                   k(0.4),
                   k(0.4),
                   k(0.4),
        ])
        
        
        plt.setp( mypie2, width=0.4, edgecolor='white')
        plt.margins(1,1) 
        fig.suptitle('Projects in eNEPA Database by Fiscal Year: '+str(int(year)))
        
        pp.savefig()
        ax.cla()
    else:
        continue
pp.close()

# %%
cmb_g
# Out:
#            names  size
# 0     Region 1:8     8
# 1    Region 2:14    14
# 2    Region 3:12    12
# 3    Region 4:35    35
# 4    Region 5:18    18
# 5    Region 6:19    19
# 6    Region 7:10    10
# 7    Region 8:31    31
# 8    Region 9:51    51
# 9   Region 10:34    34
# 10   Region 11:6     6
